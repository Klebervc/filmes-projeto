# %% [markdown]
# # Ajustes dos dados com Random Forest

# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd
import ast
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine

# %% [markdown]
# ## Criando a engine de conexão com o banco de dados

# %%
path_db = '../db/filmes.db'

engine = create_engine(f'sqlite:///{path_db}')

# %% [markdown]
# # Carregando o DataFrame

# %% [markdown]
# Vamos carregar o DataFrame partindo da databela `filmes` no banco de dados.

# %%
df = pd.read_sql('SELECT * from filmes', con=engine)

# %% [markdown]
# # Criando novas colunas

# %% [markdown]
# Partindo de que as colunas `genres` e `release_date` do `df` não servirão como `features` para inputar as colunas `budget` e `revenue`, criaremos as colunas numéricas `num_genres` e `release_year`. Para fazermos isso, primeiramente iremos transformar em `lista` os elementos da coluna `genres` que até então são `string de lista`.

# %%
df['genres'] = df['genres'].apply(ast.literal_eval)

# %% [markdown]
# Criando a coluna `num_genres`

# %%
df['num_genres'] = df['genres'].apply(lambda x: len(x) if isinstance(x, list) else 0)

# %% [markdown]
# Convertendo a coluna `release_date` para `datetimes`

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %% [markdown]
# Criando a coluna `release_year`

# %%
df['release_year'] = df['release_date'].dt.year

# %%
df
# Out:
#           id                     title                    original_title  \
# 0     411405              Small Crimes                      Small Crimes
# 1      42492            Up the Sandbox                    Up the Sandbox
# 2      12143            Bad Lieutenant                    Bad Lieutenant
# 3       9976     Satan's Little Helper             Satan's Little Helper
# 4      46761                    Sitcom                            Sitcom
# ...      ...                       ...                               ...
# 4995    3093          Basic Instinct 2                  Basic Instinct 2
# 4996  246127  Every Thing Will Be Fine          Every Thing Will Be Fine
# 4997    9803              Seven Dwarfs  7 Zwerge - Männer allein im Wald
# 4998  336970             True Siblings                        Syskonsalt
# 4999  336691           Paternity Leave                   Paternity Leave
#
#      original_language                                           overview  \
# 0                   en  A disgraced former cop, fresh off a six-year p...
# 1                   en  A young wife and mother, bored with day-to-day...
# 2                   en  While investigating a young nun's rape, a corr...
# 3                   en  A naïve young boy unknowingly becomes the pawn...
# 4                   fr  The adventures of an upper-class suburban fami...
# ...                ...                                                ...
# 4995                en  Novelist Catherine Tramell is once again in tr...
# 4996                en  One day, driving aimlessly around the outskirt...
# 4997                de  The Seven Dwarves live deep within a female-fr...
# 4998                sv  The siblings Linus, 19-years-old, who are taki...
# 4999                en  Four years into his first stable relationship,...
#
#           budget     revenue  runtime release_date  \
# 0            0.0         0.0     95.0   2017-04-28
# 1            0.0         0.0     97.0   1972-12-21
# 2      1000000.0   2019469.0     96.0   1992-09-16
# 3            0.0         0.0    100.0   2004-01-01
# 4            0.0         0.0     80.0   1998-05-27
# ...          ...         ...      ...          ...
# 4995  70000000.0  38629478.0    114.0   2006-03-29
# 4996         0.0      8034.0    118.0   2015-04-02
# 4997         0.0         0.0     95.0   2004-10-28
# 4998         0.0         0.0     58.0   2000-09-13
# 4999         0.0         0.0     90.0   2015-11-24
#
#                                 genres  popularity  vote_average  vote_count  \
# 0     [Drama, Comedy, Thriller, Crime]    7.219022           5.8        55.0
# 1                      [Drama, Comedy]    0.138450           7.3         2.0
# 2                       [Crime, Drama]    6.417037           6.9       162.0
# 3            [Horror, Romance, Comedy]    2.233189           5.0        42.0
# 4            [Comedy, Drama, Thriller]    1.800582           6.4        27.0
# ...                                ...         ...           ...         ...
# 4995        [Crime, Mystery, Thriller]   15.321902           4.6       183.0
# 4996                           [Drama]    5.723103           5.3        79.0
# 4997                          [Comedy]    4.582736           5.2        70.0
# 4998                 [Drama, TV Movie]    2.364355           8.0         2.0
# 4999                 [Comedy, Romance]    0.448056           7.0         4.0
#
#       num_genres  release_year
# 0              4        2017.0
# 1              2        1972.0
# 2              2        1992.0
# 3              3        2004.0
# 4              3        1998.0
# ...          ...           ...
# 4995           3        2006.0
# 4996           1        2015.0
# 4997           1        2004.0
# 4998           2        2000.0
# 4999           2        2015.0
#
# [5000 rows x 15 columns]

# %% [markdown]
# Agora faremos one hot encoder na coluna `original language` para também inserirmos no treinamento do modelo de florestas aleatórias.

# %%
df_encoder = pd.get_dummies(df, columns=['original_language'])

# %%
df_encoder
# Out:
#           id                     title                    original_title  \
# 0     411405              Small Crimes                      Small Crimes
# 1      42492            Up the Sandbox                    Up the Sandbox
# 2      12143            Bad Lieutenant                    Bad Lieutenant
# 3       9976     Satan's Little Helper             Satan's Little Helper
# 4      46761                    Sitcom                            Sitcom
# ...      ...                       ...                               ...
# 4995    3093          Basic Instinct 2                  Basic Instinct 2
# 4996  246127  Every Thing Will Be Fine          Every Thing Will Be Fine
# 4997    9803              Seven Dwarfs  7 Zwerge - Männer allein im Wald
# 4998  336970             True Siblings                        Syskonsalt
# 4999  336691           Paternity Leave                   Paternity Leave
#
#                                                overview      budget  \
# 0     A disgraced former cop, fresh off a six-year p...         0.0
# 1     A young wife and mother, bored with day-to-day...         0.0
# 2     While investigating a young nun's rape, a corr...   1000000.0
# 3     A naïve young boy unknowingly becomes the pawn...         0.0
# 4     The adventures of an upper-class suburban fami...         0.0
# ...                                                 ...         ...
# 4995  Novelist Catherine Tramell is once again in tr...  70000000.0
# 4996  One day, driving aimlessly around the outskirt...         0.0
# 4997  The Seven Dwarves live deep within a female-fr...         0.0
# 4998  The siblings Linus, 19-years-old, who are taki...         0.0
# 4999  Four years into his first stable relationship,...         0.0
#
#          revenue  runtime release_date                            genres  \
# 0            0.0     95.0   2017-04-28  [Drama, Comedy, Thriller, Crime]
# 1            0.0     97.0   1972-12-21                   [Drama, Comedy]
# 2      2019469.0     96.0   1992-09-16                    [Crime, Drama]
# 3            0.0    100.0   2004-01-01         [Horror, Romance, Comedy]
# 4            0.0     80.0   1998-05-27         [Comedy, Drama, Thriller]
# ...          ...      ...          ...                               ...
# 4995  38629478.0    114.0   2006-03-29        [Crime, Mystery, Thriller]
# 4996      8034.0    118.0   2015-04-02                           [Drama]
# 4997         0.0     95.0   2004-10-28                          [Comedy]
# 4998         0.0     58.0   2000-09-13                 [Drama, TV Movie]
# 4999         0.0     90.0   2015-11-24                 [Comedy, Romance]
#
#       popularity  ...  original_language_te  original_language_th  \
# 0       7.219022  ...                 False                 False
# 1       0.138450  ...                 False                 False
# 2       6.417037  ...                 False                 False
# 3       2.233189  ...                 False                 False
# 4       1.800582  ...                 False                 False
# ...          ...  ...                   ...                   ...
# 4995   15.321902  ...                 False                 False
# 4996    5.723103  ...                 False                 False
# 4997    4.582736  ...                 False                 False
# 4998    2.364355  ...                 False                 False
# 4999    0.448056  ...                 False                 False
#
#       original_language_tl  original_language_tr  original_language_uk  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 4995                 False                 False                 False
# 4996                 False                 False                 False
# 4997                 False                 False                 False
# 4998                 False                 False                 False
# 4999                 False                 False                 False
#
#       original_language_ur  original_language_uz  original_language_vi  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 4995                 False                 False                 False
# 4996                 False                 False                 False
# 4997                 False                 False                 False
# 4998                 False                 False                 False
# 4999                 False                 False                 False
#
#       original_language_xx  original_language_zh
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                 False
# ...                    ...                   ...
# 4995                 False                 False
# 4996                 False                 False
# 4997                 False                 False
# 4998                 False                 False
# 4999                 False                 False
#
# [5000 rows x 72 columns]

# %% [markdown]
# # Inputando as colunas Budget e Revenue

# %%
df_encoder.columns
# Out:
# Index(['id', 'title', 'original_title', 'overview', 'budget', 'revenue',
#        'runtime', 'release_date', 'genres', 'popularity', 'vote_average',
#        'vote_count', 'num_genres', 'release_year', 'original_language_ar',
#        'original_language_ay', 'original_language_bg', 'original_language_bn',
#        'original_language_ca', 'original_language_cn', 'original_language_cs',
#        'original_language_da', 'original_language_de', 'original_language_el',
#        'original_language_en', 'original_language_es', 'original_language_et',
#        'original_language_fa', 'original_language_fi', 'original_language_fr',
#        'original_language_he', 'original_language_hi', 'original_language_hr',
#        'original_language_hu', 'original_language_id', 'original_language_is',
#        'original_language_it', 'original_language_iu', 'original_language_ja',
#        'original_language_ka', 'original_language_ko', 'original_language_lv',
#        'original_language_mk', 'original_language_ml', 'original_language_mn',
#        'original_language_mr', 'original_language_ms', 'original_language_nb',
#        'original_language_nl', 'original_language_no', 'original_language_pa',
#        'original_language_pl', 'original_language_ps', 'original_language_pt',
#        'original_language_ro', 'original_language_ru', 'original_language_sk',
#        'original_language_sl', 'original_language_sq', 'original_language_sr',
#        'original_language_sv', 'original_language_ta', 'original_language_te',
#        'original_language_th', 'original_language_tl', 'original_language_tr',
#        'original_language_uk', 'original_language_ur', 'original_language_uz',
#        'original_language_vi', 'original_language_xx', 'original_language_zh'],
#       dtype='object')

# %% [markdown]
# Aqui temos as colunas de `features` que servirão para o treinamento e previsão do modelo.

# %%
features = ['runtime', 'popularity', 'vote_average', 'vote_count', 'num_genres', 'release_year', 'original_language_ar',
       'original_language_ay', 'original_language_bg', 'original_language_bn',
       'original_language_ca', 'original_language_cn', 'original_language_cs',
       'original_language_da', 'original_language_de', 'original_language_el',
       'original_language_en', 'original_language_es', 'original_language_et',
       'original_language_fa', 'original_language_fi', 'original_language_fr',
       'original_language_he', 'original_language_hi', 'original_language_hr',
       'original_language_hu', 'original_language_id', 'original_language_is',
       'original_language_it', 'original_language_iu', 'original_language_ja',
       'original_language_ka', 'original_language_ko', 'original_language_lv',
       'original_language_mk', 'original_language_ml', 'original_language_mn',
       'original_language_mr', 'original_language_ms', 'original_language_nb',
       'original_language_nl', 'original_language_no', 'original_language_pa',
       'original_language_pl', 'original_language_ps', 'original_language_pt',
       'original_language_ro', 'original_language_ru', 'original_language_sk',
       'original_language_sl', 'original_language_sq', 'original_language_sr',
       'original_language_sv', 'original_language_ta', 'original_language_te',
       'original_language_th', 'original_language_tl', 'original_language_tr',
       'original_language_uk', 'original_language_ur', 'original_language_uz',
       'original_language_vi', 'original_language_xx', 'original_language_zh']

# %% [markdown]
# Antes de inputar as colunas vamos avaliar o desempenho do modelo de Florestas Aleatórias pelo Erro Absoluto Médio `(MAE)`. Essa métrica é uma das mais indicadas para inputar valores em colunas por regressão de Florestas Aleatórias, pois são robustos a outliers já que tratam todos os erros da mesma forma controlando o erro médio.

# %%
def avaliar_modelo(df, coluna_alvo):
    
    df_completo = df[df[coluna_alvo] != 0]
    
    df_train, df_test = train_test_split(df_completo, test_size=0.2, random_state=42)
    
    X_train = df_train.drop(columns=[coluna_alvo])
    Y_train = df_train[coluna_alvo]
    
    X_test = df_test.drop(columns=[coluna_alvo])
    Y_test = df_test[coluna_alvo]
    
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, Y_train)
    
    Y_pred = model.predict(X_test)
    
    mae = mean_absolute_error(Y_pred, Y_test)
    
    return mae

# %% [markdown]
# Temos, portanto, que para a coluna `budget` o modelo erra cerca de `R$ 27414697.98` ao prever o valor na inputação. Para termos uma melhor noção se esse erro é bom ou ruim precisamos comparar com o valor típico (média) dos orçamentos.

# %%
mae_budget = avaliar_modelo(df_encoder[features + ['budget']], 'budget')
mae_budget
# Out:
# 27414697.97788889

# %%
budeget_test = df_encoder[df_encoder['budget'] != 0]

# %%
budeget_test.mean(numeric_only=True)
# Out:
# id                      7.976318e+04
# budget                  1.316451e+08
# revenue                 4.835092e+07
# runtime                 1.046956e+02
# popularity              7.749254e+00
#                             ...
# original_language_ur    0.000000e+00
# original_language_uz    0.000000e+00
# original_language_vi    1.111111e-03
# original_language_xx    0.000000e+00
# original_language_zh    3.333333e-03
# Length: 67, dtype: float64

# %% [markdown]
# Obtemos a média de `budget` no valor de `R$ 131.645.100` que é compatível para orçamentos de filmes e fazendo a comparação com o MAE de budget temos um __erro__ __relativo__ de aproximadamente `21%`. Isso significa que aproximadamente o modelo erra `21%` do valor médio do orçamento e isso é aceitavel em dados financeiros ou orçamentos que possuem alta variabilidade. Logo, a previsão não é muito precisa mas o modelo está capturando padrões úteis nos dados. Podemos dizer que a previsão está boa.

# %%
relative_mae = mae_budget / (budeget_test['budget'].mean())

print(f"Erro relativo médio: {relative_mae:.2%}")
# Out:
# Erro relativo médio: 20.82%

# %% [markdown]
# Já na coluna `revenue` o modelo erra aproximadamente `R$ 36341298.47` ao fazer uma previsão.`

# %%
mae_revenue = avaliar_modelo(df_encoder[features + ['revenue']], 'revenue')
mae_revenue
# Out:
# 36341298.4694375

# %% [markdown]
# Fazendo a comparação com a média dos valores em `revenue` obtemos um erro relativo de aproximadamente `60%` o que é um valor bastante alto mas isso condiz com a grande variabilidade dos dados nessa coluna pois temos um alto desvio padrão de __R$ 123 milhões__, aproximadamente. Isso significa que há uma grande dispersão dos dados em torno da média o que é comum em datasets de filmes com uns arrecadando poucos milhões e outros bilhões e isso dificulta previsões mais precisas de modelos com erros baixos. Como o MAE de `revenue` é aproximadamente `R$ 36341298.47` o modelo está errando menos do que a variabilidade natural dos dados, ou seja, está aprendendo algo útil e não apenas chutando valores. O MAE de `revenue` é grande mas razoável em relação a disperção dos dados.

# %%
revenue_test = df_encoder[df_encoder['revenue'] != 0]

# %%
revenue_test.describe()
# Out:
#                   id        budget       revenue     runtime  \
# count     798.000000  7.980000e+02  7.980000e+02  798.000000
# mean    66150.689223  1.968500e+07  6.071100e+07  107.892231
# min        13.000000  0.000000e+00 -5.000000e+04    0.000000
# 25%      9570.750000  0.000000e+00  1.917916e+06   94.000000
# 50%     19121.000000  5.000000e+06  1.579941e+07  102.500000
# 75%     70766.250000  2.500000e+07  6.372200e+07  119.000000
# max    428449.000000  2.600000e+08  1.156731e+09  216.000000
# std     97616.195715  3.337015e+07  1.233122e+08   22.236178
#
#                         release_date  popularity  vote_average   vote_count  \
# count                            780  798.000000    798.000000   798.000000
# mean   1999-06-14 01:50:46.153846144    8.655179      6.198496   517.817043
# min              1918-08-01 00:00:00    0.001223      0.000000     0.000000
# 25%              1992-11-22 00:00:00    3.851706      5.625000    36.000000
# 50%              2004-01-17 12:00:00    7.419201      6.300000   152.500000
# 75%              2011-02-16 00:00:00   10.743956      6.900000   522.500000
# max              2017-08-04 00:00:00  547.488298      8.500000  8670.000000
# std                              NaN   20.578149      1.078185   995.938961
#
#        num_genres  release_year
# count  798.000000    780.000000
# mean     2.464912   1998.910256
# min      0.000000   1918.000000
# 25%      2.000000   1992.000000
# 50%      2.000000   2003.500000
# 75%      3.000000   2011.000000
# max      6.000000   2017.000000
# std      1.090922     16.789328

# %%
relative_mae = mae_revenue/revenue_test['revenue'].mean()

print(f"Erro relativo médio: {relative_mae:.2%}")
# Out:
# Erro relativo médio: 59.86%

# %% [markdown]
# Agora vamos inputar as colunas `budget` e `revenue` com o modelo.

# %%
def inputar_coluna(df, coluna_alvo, colunas):
    
    valido = ~df[colunas].isna().any(axis=1)
    
    X_train = df.loc[valido & (df[coluna_alvo] != 0), colunas]
    Y_train = df.loc[valido & (df[coluna_alvo] != 0), coluna_alvo]
    X_pred = df.loc[valido & (df[coluna_alvo] == 0), colunas]
    
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, Y_train)
    
    Y_pred = model.predict(X_pred)
    
    df.loc[X_pred.index, coluna_alvo] = Y_pred
    
    return df

# %%
df_budget = inputar_coluna(df_encoder, 'budget', features)
df_budget
# Out:
#           id                     title                    original_title  \
# 0     411405              Small Crimes                      Small Crimes
# 1      42492            Up the Sandbox                    Up the Sandbox
# 2      12143            Bad Lieutenant                    Bad Lieutenant
# 3       9976     Satan's Little Helper             Satan's Little Helper
# 4      46761                    Sitcom                            Sitcom
# ...      ...                       ...                               ...
# 4995    3093          Basic Instinct 2                  Basic Instinct 2
# 4996  246127  Every Thing Will Be Fine          Every Thing Will Be Fine
# 4997    9803              Seven Dwarfs  7 Zwerge - Männer allein im Wald
# 4998  336970             True Siblings                        Syskonsalt
# 4999  336691           Paternity Leave                   Paternity Leave
#
#                                                overview       budget  \
# 0     A disgraced former cop, fresh off a six-year p...  12365792.57
# 1     A young wife and mother, bored with day-to-day...    629789.52
# 2     While investigating a young nun's rape, a corr...   1000000.00
# 3     A naïve young boy unknowingly becomes the pawn...   5580448.55
# 4     The adventures of an upper-class suburban fami...   2930791.96
# ...                                                 ...          ...
# 4995  Novelist Catherine Tramell is once again in tr...  70000000.00
# 4996  One day, driving aimlessly around the outskirt...  15751313.18
# 4997  The Seven Dwarves live deep within a female-fr...  12795408.80
# 4998  The siblings Linus, 19-years-old, who are taki...   3307811.75
# 4999  Four years into his first stable relationship,...   1037663.31
#
#          revenue  runtime release_date                            genres  \
# 0            0.0     95.0   2017-04-28  [Drama, Comedy, Thriller, Crime]
# 1            0.0     97.0   1972-12-21                   [Drama, Comedy]
# 2      2019469.0     96.0   1992-09-16                    [Crime, Drama]
# 3            0.0    100.0   2004-01-01         [Horror, Romance, Comedy]
# 4            0.0     80.0   1998-05-27         [Comedy, Drama, Thriller]
# ...          ...      ...          ...                               ...
# 4995  38629478.0    114.0   2006-03-29        [Crime, Mystery, Thriller]
# 4996      8034.0    118.0   2015-04-02                           [Drama]
# 4997         0.0     95.0   2004-10-28                          [Comedy]
# 4998         0.0     58.0   2000-09-13                 [Drama, TV Movie]
# 4999         0.0     90.0   2015-11-24                 [Comedy, Romance]
#
#       popularity  ...  original_language_te  original_language_th  \
# 0       7.219022  ...                 False                 False
# 1       0.138450  ...                 False                 False
# 2       6.417037  ...                 False                 False
# 3       2.233189  ...                 False                 False
# 4       1.800582  ...                 False                 False
# ...          ...  ...                   ...                   ...
# 4995   15.321902  ...                 False                 False
# 4996    5.723103  ...                 False                 False
# 4997    4.582736  ...                 False                 False
# 4998    2.364355  ...                 False                 False
# 4999    0.448056  ...                 False                 False
#
#       original_language_tl  original_language_tr  original_language_uk  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 4995                 False                 False                 False
# 4996                 False                 False                 False
# 4997                 False                 False                 False
# 4998                 False                 False                 False
# 4999                 False                 False                 False
#
#       original_language_ur  original_language_uz  original_language_vi  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 4995                 False                 False                 False
# 4996                 False                 False                 False
# 4997                 False                 False                 False
# 4998                 False                 False                 False
# 4999                 False                 False                 False
#
#       original_language_xx  original_language_zh
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                 False
# ...                    ...                   ...
# 4995                 False                 False
# 4996                 False                 False
# 4997                 False                 False
# 4998                 False                 False
# 4999                 False                 False
#
# [5000 rows x 72 columns]

# %%
(df_budget['budget'] == 0).sum()
# Out:
# 87

# %%
df_revenue = inputar_coluna(df_encoder, 'revenue', features)
df_revenue
# Out:
#           id                     title                    original_title  \
# 0     411405              Small Crimes                      Small Crimes
# 1      42492            Up the Sandbox                    Up the Sandbox
# 2      12143            Bad Lieutenant                    Bad Lieutenant
# 3       9976     Satan's Little Helper             Satan's Little Helper
# 4      46761                    Sitcom                            Sitcom
# ...      ...                       ...                               ...
# 4995    3093          Basic Instinct 2                  Basic Instinct 2
# 4996  246127  Every Thing Will Be Fine          Every Thing Will Be Fine
# 4997    9803              Seven Dwarfs  7 Zwerge - Männer allein im Wald
# 4998  336970             True Siblings                        Syskonsalt
# 4999  336691           Paternity Leave                   Paternity Leave
#
#                                                overview       budget  \
# 0     A disgraced former cop, fresh off a six-year p...  12365792.57
# 1     A young wife and mother, bored with day-to-day...    629789.52
# 2     While investigating a young nun's rape, a corr...   1000000.00
# 3     A naïve young boy unknowingly becomes the pawn...   5580448.55
# 4     The adventures of an upper-class suburban fami...   2930791.96
# ...                                                 ...          ...
# 4995  Novelist Catherine Tramell is once again in tr...  70000000.00
# 4996  One day, driving aimlessly around the outskirt...  15751313.18
# 4997  The Seven Dwarves live deep within a female-fr...  12795408.80
# 4998  The siblings Linus, 19-years-old, who are taki...   3307811.75
# 4999  Four years into his first stable relationship,...   1037663.31
#
#           revenue  runtime release_date                            genres  \
# 0      3111954.14     95.0   2017-04-28  [Drama, Comedy, Thriller, Crime]
# 1      1354322.31     97.0   1972-12-21                   [Drama, Comedy]
# 2      2019469.00     96.0   1992-09-16                    [Crime, Drama]
# 3     11719114.63    100.0   2004-01-01         [Horror, Romance, Comedy]
# 4      6196771.07     80.0   1998-05-27         [Comedy, Drama, Thriller]
# ...           ...      ...          ...                               ...
# 4995  38629478.00    114.0   2006-03-29        [Crime, Mystery, Thriller]
# 4996      8034.00    118.0   2015-04-02                           [Drama]
# 4997  16461042.70     95.0   2004-10-28                          [Comedy]
# 4998  25709208.27     58.0   2000-09-13                 [Drama, TV Movie]
# 4999    607434.50     90.0   2015-11-24                 [Comedy, Romance]
#
#       popularity  ...  original_language_te  original_language_th  \
# 0       7.219022  ...                 False                 False
# 1       0.138450  ...                 False                 False
# 2       6.417037  ...                 False                 False
# 3       2.233189  ...                 False                 False
# 4       1.800582  ...                 False                 False
# ...          ...  ...                   ...                   ...
# 4995   15.321902  ...                 False                 False
# 4996    5.723103  ...                 False                 False
# 4997    4.582736  ...                 False                 False
# 4998    2.364355  ...                 False                 False
# 4999    0.448056  ...                 False                 False
#
#       original_language_tl  original_language_tr  original_language_uk  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 4995                 False                 False                 False
# 4996                 False                 False                 False
# 4997                 False                 False                 False
# 4998                 False                 False                 False
# 4999                 False                 False                 False
#
#       original_language_ur  original_language_uz  original_language_vi  \
# 0                    False                 False                 False
# 1                    False                 False                 False
# 2                    False                 False                 False
# 3                    False                 False                 False
# 4                    False                 False                 False
# ...                    ...                   ...                   ...
# 4995                 False                 False                 False
# 4996                 False                 False                 False
# 4997                 False                 False                 False
# 4998                 False                 False                 False
# 4999                 False                 False                 False
#
#       original_language_xx  original_language_zh
# 0                    False                 False
# 1                    False                 False
# 2                    False                 False
# 3                    False                 False
# 4                    False                 False
# ...                    ...                   ...
# 4995                 False                 False
# 4996                 False                 False
# 4997                 False                 False
# 4998                 False                 False
# 4999                 False                 False
#
# [5000 rows x 72 columns]

# %%
(df_revenue['revenue'] == 0).sum()
# Out:
# 96

# %% [markdown]
# # Salvando o novo dataset no banco de dados

# %% [markdown]
# Primeiro vamos desfazer o one hot encoder para a coluna de `original_language` de antes.

# %%
df[['budget', 'revenue']] = df_revenue[['budget', 'revenue']]

# %%
df
# Out:
#           id                     title                    original_title  \
# 0     411405              Small Crimes                      Small Crimes
# 1      42492            Up the Sandbox                    Up the Sandbox
# 2      12143            Bad Lieutenant                    Bad Lieutenant
# 3       9976     Satan's Little Helper             Satan's Little Helper
# 4      46761                    Sitcom                            Sitcom
# ...      ...                       ...                               ...
# 4995    3093          Basic Instinct 2                  Basic Instinct 2
# 4996  246127  Every Thing Will Be Fine          Every Thing Will Be Fine
# 4997    9803              Seven Dwarfs  7 Zwerge - Männer allein im Wald
# 4998  336970             True Siblings                        Syskonsalt
# 4999  336691           Paternity Leave                   Paternity Leave
#
#      original_language                                           overview  \
# 0                   en  A disgraced former cop, fresh off a six-year p...
# 1                   en  A young wife and mother, bored with day-to-day...
# 2                   en  While investigating a young nun's rape, a corr...
# 3                   en  A naïve young boy unknowingly becomes the pawn...
# 4                   fr  The adventures of an upper-class suburban fami...
# ...                ...                                                ...
# 4995                en  Novelist Catherine Tramell is once again in tr...
# 4996                en  One day, driving aimlessly around the outskirt...
# 4997                de  The Seven Dwarves live deep within a female-fr...
# 4998                sv  The siblings Linus, 19-years-old, who are taki...
# 4999                en  Four years into his first stable relationship,...
#
#            budget      revenue  runtime release_date  \
# 0     12365792.57   3111954.14     95.0   2017-04-28
# 1       629789.52   1354322.31     97.0   1972-12-21
# 2      1000000.00   2019469.00     96.0   1992-09-16
# 3      5580448.55  11719114.63    100.0   2004-01-01
# 4      2930791.96   6196771.07     80.0   1998-05-27
# ...           ...          ...      ...          ...
# 4995  70000000.00  38629478.00    114.0   2006-03-29
# 4996  15751313.18      8034.00    118.0   2015-04-02
# 4997  12795408.80  16461042.70     95.0   2004-10-28
# 4998   3307811.75  25709208.27     58.0   2000-09-13
# 4999   1037663.31    607434.50     90.0   2015-11-24
#
#                                 genres  popularity  vote_average  vote_count  \
# 0     [Drama, Comedy, Thriller, Crime]    7.219022           5.8        55.0
# 1                      [Drama, Comedy]    0.138450           7.3         2.0
# 2                       [Crime, Drama]    6.417037           6.9       162.0
# 3            [Horror, Romance, Comedy]    2.233189           5.0        42.0
# 4            [Comedy, Drama, Thriller]    1.800582           6.4        27.0
# ...                                ...         ...           ...         ...
# 4995        [Crime, Mystery, Thriller]   15.321902           4.6       183.0
# 4996                           [Drama]    5.723103           5.3        79.0
# 4997                          [Comedy]    4.582736           5.2        70.0
# 4998                 [Drama, TV Movie]    2.364355           8.0         2.0
# 4999                 [Comedy, Romance]    0.448056           7.0         4.0
#
#       num_genres  release_year
# 0              4        2017.0
# 1              2        1972.0
# 2              2        1992.0
# 3              3        2004.0
# 4              3        1998.0
# ...          ...           ...
# 4995           3        2006.0
# 4996           1        2015.0
# 4997           1        2004.0
# 4998           2        2000.0
# 4999           2        2015.0
#
# [5000 rows x 15 columns]

# %% [markdown]
# Vamos mudar os registros em `genres` para `strings` para salvarmos no banco de dados já que não é permitido salvar como listas.

# %%
df['genres'] = df['genres'].apply(lambda x: str(x))

# %%
df
# Out:
#           id                     title                    original_title  \
# 0     411405              Small Crimes                      Small Crimes
# 1      42492            Up the Sandbox                    Up the Sandbox
# 2      12143            Bad Lieutenant                    Bad Lieutenant
# 3       9976     Satan's Little Helper             Satan's Little Helper
# 4      46761                    Sitcom                            Sitcom
# ...      ...                       ...                               ...
# 4995    3093          Basic Instinct 2                  Basic Instinct 2
# 4996  246127  Every Thing Will Be Fine          Every Thing Will Be Fine
# 4997    9803              Seven Dwarfs  7 Zwerge - Männer allein im Wald
# 4998  336970             True Siblings                        Syskonsalt
# 4999  336691           Paternity Leave                   Paternity Leave
#
#      original_language                                           overview  \
# 0                   en  A disgraced former cop, fresh off a six-year p...
# 1                   en  A young wife and mother, bored with day-to-day...
# 2                   en  While investigating a young nun's rape, a corr...
# 3                   en  A naïve young boy unknowingly becomes the pawn...
# 4                   fr  The adventures of an upper-class suburban fami...
# ...                ...                                                ...
# 4995                en  Novelist Catherine Tramell is once again in tr...
# 4996                en  One day, driving aimlessly around the outskirt...
# 4997                de  The Seven Dwarves live deep within a female-fr...
# 4998                sv  The siblings Linus, 19-years-old, who are taki...
# 4999                en  Four years into his first stable relationship,...
#
#            budget      revenue  runtime release_date  \
# 0     12365792.57   3111954.14     95.0   2017-04-28
# 1       629789.52   1354322.31     97.0   1972-12-21
# 2      1000000.00   2019469.00     96.0   1992-09-16
# 3      5580448.55  11719114.63    100.0   2004-01-01
# 4      2930791.96   6196771.07     80.0   1998-05-27
# ...           ...          ...      ...          ...
# 4995  70000000.00  38629478.00    114.0   2006-03-29
# 4996  15751313.18      8034.00    118.0   2015-04-02
# 4997  12795408.80  16461042.70     95.0   2004-10-28
# 4998   3307811.75  25709208.27     58.0   2000-09-13
# 4999   1037663.31    607434.50     90.0   2015-11-24
#
#                                         genres  popularity  vote_average  \
# 0     ['Drama', 'Comedy', 'Thriller', 'Crime']    7.219022           5.8
# 1                          ['Drama', 'Comedy']    0.138450           7.3
# 2                           ['Crime', 'Drama']    6.417037           6.9
# 3              ['Horror', 'Romance', 'Comedy']    2.233189           5.0
# 4              ['Comedy', 'Drama', 'Thriller']    1.800582           6.4
# ...                                        ...         ...           ...
# 4995          ['Crime', 'Mystery', 'Thriller']   15.321902           4.6
# 4996                                 ['Drama']    5.723103           5.3
# 4997                                ['Comedy']    4.582736           5.2
# 4998                     ['Drama', 'TV Movie']    2.364355           8.0
# 4999                     ['Comedy', 'Romance']    0.448056           7.0
#
#       vote_count  num_genres  release_year
# 0           55.0           4        2017.0
# 1            2.0           2        1972.0
# 2          162.0           2        1992.0
# 3           42.0           3        2004.0
# 4           27.0           3        1998.0
# ...          ...         ...           ...
# 4995       183.0           3        2006.0
# 4996        79.0           1        2015.0
# 4997        70.0           1        2004.0
# 4998         2.0           2        2000.0
# 4999         4.0           2        2015.0
#
# [5000 rows x 15 columns]

# %% [markdown]
# Agora vamos salvar o novo dataframe no banco de dados.

# %%
df.to_sql('filmes', con=engine, if_exists='replace', index=False)
# Out:
# 5000
